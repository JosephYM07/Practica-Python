# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
fruits=['apple','orange','cherry','grape','blueberry']
quantities=[5,3,6,2,3]

# %%
#Series
S=pd.Series(fruits,quantities)

# %%
S
# Out:
# 5        apple
# 3       orange
# 6       cherry
# 2        grape
# 3    blueberry
# dtype: object

# %% [markdown]
# # DataFrame

# %%
frutas_costa=['Platano','coco','piña']
frutas_sierra=['mandarina','guaba','chirimoya']
index=["a,b,c".split(",")]

# %%
todas_las_frutas={'Costa':frutas_costa,'Sierra':frutas_sierra}
print(todas_las_frutas)
# Out:
# {'Costa': ['Platano', 'coco', 'piña'], 'Sierra': ['mandarina', 'guaba', 'chirimoya']}

# %% [markdown]
# Frutas indexadas

# %%
frutas_indexadas=pd.DataFrame(todas_las_frutas,index=index)
print(frutas_indexadas)
# Out:
#      Costa     Sierra
# a  Platano  mandarina
# b     coco      guaba
# c     piña  chirimoya

# %%
frutas_indexadas.to_csv('frutas.csv')

# %%
frutas_indexadas.to_json('frutas.json')

# %%
df=pd.read_csv('frutas.csv',index_col=0)

# %%
df
# Out:
#      Costa     Sierra
# a  Platano  mandarina
# b     coco      guaba
# c     piña  chirimoya

# %%
df2=pd.read_json('frutas.json')

# %%
df2
# Out:
#           Costa     Sierra
# ('a',)  Platano  mandarina
# ('b',)     coco      guaba
# ('c',)     piña  chirimoya

# %%
cars=['BMW','Toyota','Ford','Mazda','Mercedes']
colors=['Red','Blue','White','Black','Green']
precies=[50000,25000,30000,35000,45000]
index=['a','b','c','d','e']

# %%
cars_indexed=pd.DataFrame({'Cars':cars,'Colors':colors,'Precies':precies},index=index)

# %%
cars_indexed
# Out:
#        Cars Colors  Precies
# a       BMW    Red    50000
# b    Toyota   Blue    25000
# c      Ford  White    30000
# d     Mazda  Black    35000
# e  Mercedes  Green    45000

# %%
cars_indexed.to_json('cars.json')

# %%
df2=pd.read_json('cars.json')

# %%
df2
# Out:
#        Cars Colors  Precies
# a       BMW    Red    50000
# b    Toyota   Blue    25000
# c      Ford  White    30000
# d     Mazda  Black    35000
# e  Mercedes  Green    45000

# %% [markdown]
# # SQLITE

# %%
import sqlite3

# %%
con=sqlite3.connect("database.db")

# %%
dff=pd.read_sql_query("SELECT * FROM compras",con)

# %%
dff
# Out:
#    index  apples  oranges
# 0      1       2        5
# 1      2       4        5
# 2      3       5        4
# 3      5       7        8
# 4      5       7        9

# %%
con=sqlite3.connect("canasta.db")

# %%
dff=pd.read_sql_query("SELECT * FROM canasta",con)

# %%
dff
# Out:
#                  Alex    Joseph    Alexis      Jared          Monica  \
# 0                 Pan     Leche    Huevos  Chocolate          Harina
# 1            Frutaris      Atun  Lentejas    Tomates      Garatorade
# 2               Arroz  Cilantro        Té    Monster  Arroz Integral
# 3  Polvo para Hornear  Galletas       Pan       Cafe          Fideos
# 4              Huevos    Harina      Cafe        Sal           Leche
#
#          Alejandro Roberto       Elvis    Camila    Paula
# 0           Fideos    Cafe     Machica  Manzanas  Doritos
# 1  Botella de Agua     Sal      Frejol      Maiz   Azucar
# 2         Cebollas   Queso  Deterjente  Pinoclin   Escoba
# 3          Machica  Frejol       Queso   Nutella    Leche
# 4         Cebollas  Azucar    Cilantro        Te     Atun

# %% [markdown]
# # Cargar un cvs

# %%
movies_df=pd.read_csv("IMDB-Movie-Data.csv",index_col="Title")

# %%
movies_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df = pd.read_csv("https://raw.githubusercontent.com/LearnDataSci/articles/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/IMDB-Movie-Data.csv", index_col="Title")

# %%
movies_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
movies_df.tail()
# Out:
#                         Rank                  Genre  \
# Title
# Secret in Their Eyes     996    Crime,Drama,Mystery
# Hostel: Part II          997                 Horror
# Step Up 2: The Streets   998    Drama,Music,Romance
# Search Party             999       Adventure,Comedy
# Nine Lives              1000  Comedy,Family,Fantasy
#
#                                                               Description  \
# Title
# Secret in Their Eyes    A tight-knit team of rising investigators, alo...
# Hostel: Part II         Three American college students studying abroa...
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 Director  \
# Title
# Secret in Their Eyes           Billy Ray
# Hostel: Part II                 Eli Roth
# Step Up 2: The Streets        Jon M. Chu
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
movies_df.shape
# Out:
# (1000, 11)

# %% [markdown]
# # Manejo de duplicados de un dataSet

# %%
temp_df = pd.concat([movies_df, movies_df])

# %%
temp_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
temp_df=temp_df.drop_duplicates()

# %%
temp_df.shape
# Out:
# (1000, 11)

# %%
movies_df = pd.read_csv("https://raw.githubusercontent.com/LearnDataSci/articles/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/IMDB-Movie-Data.csv", index_col="Title")

# %%
movies_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.isnull().sum()
# Out:
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
#Copia de respaldo
m2=movies_df.dropna()

# %%
m2
# Out:
#                           Rank                     Genre  \
# Title
# Guardians of the Galaxy      1   Action,Adventure,Sci-Fi
# Prometheus                   2  Adventure,Mystery,Sci-Fi
# Split                        3           Horror,Thriller
# Sing                         4   Animation,Comedy,Family
# Suicide Squad                5  Action,Adventure,Fantasy
# ...                        ...                       ...
# Resident Evil: Afterlife   994   Action,Adventure,Horror
# Project X                  995                    Comedy
# Hostel: Part II            997                    Horror
# Step Up 2: The Streets     998       Drama,Music,Romance
# Nine Lives                1000     Comedy,Family,Fantasy
#
#                                                                 Description  \
# Title
# Guardians of the Galaxy   A group of intergalactic criminals are forced ...
# Prometheus                Following clues to the origin of mankind, a te...
# ...

# %%
m2.isnull().sum()
# Out:
# Rank                  0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
revenue=movies_df['Revenue (Millions)']

# %%
revenue
# Out:
# Title
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
#                             ...
# Secret in Their Eyes          NaN
# Hostel: Part II             17.54
# Step Up 2: The Streets      58.01
# Search Party                  NaN
# Nine Lives                  19.64
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
revenue_mean=revenue.mean()
revenue_mean
# Out:
# 82.95637614678898

# %%
revenue.fillna(revenue_mean,inplace=True)

# %%
movies_df.isnull().sum()
# Out:
# Rank                   0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)     0
# Metascore             64
# dtype: int64

# %%
Metascore=movies_df['Metascore']

# %%
Metascore_mean=Metascore.mean()

# %%
Metascore_mean
# Out:
# 58.98504273504273

# %%
Metascore.fillna(revenue_mean,inplace=True)

# %%
movies_df.isnull().sum()
# Out:
# Rank                  0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
movies_df['Genre'].describe()
# Out:
# count                        1000
# unique                        207
# top       Action,Adventure,Sci-Fi
# freq                           50
# Name: Genre, dtype: object

# %%
movies_df['Genre'].value_counts().head(10)
# Out:
# Action,Adventure,Sci-Fi       50
# Drama                         48
# Comedy,Drama,Romance          35
# Comedy                        32
# Drama,Romance                 31
# Animation,Adventure,Comedy    27
# Action,Adventure,Fantasy      27
# Comedy,Drama                  27
# Comedy,Romance                26
# Crime,Drama,Thriller          24
# Name: Genre, dtype: int64

# %%
movies_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df['Rank'].describe()
# Out:
# count    1000.000000
# mean      500.500000
# std       288.819436
# min         1.000000
# 25%       250.750000
# 50%       500.500000
# 75%       750.250000
# max      1000.000000
# Name: Rank, dtype: float64

# %%
movies_df['Director'].value_counts().head(10)
# Out:
# Ridley Scott          8
# David Yates           6
# M. Night Shyamalan    6
# Paul W.S. Anderson    6
# Michael Bay           6
# Zack Snyder           5
# Denis Villeneuve      5
# Woody Allen           5
# Peter Berg            5
# Danny Boyle           5
# Name: Director, dtype: int64

# %% [markdown]
# La conclusión de los datos visualizados es que hay varios directores que han dirigido un número significativo de películas

# %%
movies_df['Actors'].value_counts().head(10)
# Out:
# Jennifer Lawrence, Josh Hutcherson, Liam Hemsworth, Woody Harrelson     2
# Daniel Radcliffe, Emma Watson, Rupert Grint, Michael Gambon             2
# Shia LaBeouf, Megan Fox, Josh Duhamel, Tyrese Gibson                    2
# Gerard Butler, Aaron Eckhart, Morgan Freeman,Angela Bassett             2
# Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana                    1
# Ethan Hawke, David Thewlis, Emma Watson,Dale Dickey                     1
# Leonardo DiCaprio, Djimon Hounsou, Jennifer Connelly, Kagiso Kuypers    1
# Mark Wahlberg, Dwayne Johnson, Anthony Mackie,Tony Shalhoub             1
# Mark Wahlberg, Seth MacFarlane, Amanda Seyfried, Jessica Barth          1
# Isabelle Huppert, André Marcon, Roman Kolinka,Edith Scob                1
# Name: Actors, dtype: int64

# %% [markdown]
# La conclusión de los datos visualizados es que hay varios conjuntos de actores que han aparecido juntos en distintas películas. Estos de actores han trabajado en al menos dos películas juntos.

# %%
movies_df[(movies_df['Director'] == 'Christopher Nolan') | (movies_df['Director'] == 'Ridley Scott')].head()
# Out:
#                  Rank                     Genre  \
# Title
# Prometheus          2  Adventure,Mystery,Sci-Fi
# Interstellar       37    Adventure,Drama,Sci-Fi
# The Dark Knight    55        Action,Crime,Drama
# The Prestige       65      Drama,Mystery,Sci-Fi
# Inception          81   Action,Adventure,Sci-Fi
#
#                                                        Description  \
# Title
# Prometheus       Following clues to the origin of mankind, a te...
# Interstellar     A team of explorers travel through a wormhole ...
# The Dark Knight  When the menace known as the Joker wreaks havo...
# The Prestige     Two stage magicians engage in competitive one-...
# Inception        A thief, who steals corporate secrets through ...
#
#                           Director  \
# Title
# Prometheus            Ridley Scott
# Interstellar     Christopher Nolan
# The Dark Knight  Christopher Nolan
# The Prestige     Christopher Nolan
# Inception        Christopher Nolan
#
# ...

# %%
movies_df[ ((movies_df['Votes'] >= 100000) & (movies_df['Votes'] <= 1000000))& (movies_df['Metascore'] > 10.000000)]
# Out:
#                                 Rank                     Genre  \
# Title
# Guardians of the Galaxy            1   Action,Adventure,Sci-Fi
# Prometheus                         2  Adventure,Mystery,Sci-Fi
# Split                              3           Horror,Thriller
# Suicide Squad                      5  Action,Adventure,Fantasy
# La La Land                         7        Comedy,Drama,Music
# ...                              ...                       ...
# Let's Be Cops                    984                    Comedy
# Underworld: Rise of the Lycans   991  Action,Adventure,Fantasy
# Taare Zameen Par                 992        Drama,Family,Music
# Resident Evil: Afterlife         994   Action,Adventure,Horror
# Project X                        995                    Comedy
#
#                                                                       Description  \
# Title
# Guardians of the Galaxy         A group of intergalactic criminals are forced ...
# ...

# %% [markdown]
#  El código encuentra la película o películas con la descripción más larga en el DataFrame 'movies_df' y las almacena en el DataFrame 'Descripcion'.

# %%
max_letras = movies_df['Description'].str.len().max()
print("Numero de letras: ",max_letras)
Descripcion = movies_df[movies_df['Description'].str.len() == max_length]
Descripcion
# Out:
# Numero de letras:  421
#             Rank                  Genre  \
# Title
# RocknRolla   323  Action,Crime,Thriller
#
#                                                   Description     Director  \
# Title
# RocknRolla  In London, a real-estate scam puts millions of...  Guy Ritchie
#
#                                                        Actors  Year  \
# Title
# RocknRolla  Gerard Butler, Tom Wilkinson, Idris Elba, Than...  2008
#
#             Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# Title
# RocknRolla                114     7.3  203096                5.69       53.0

# %%
movies_df[ ((movies_df['Year'] >= 2005) & (movies_df['Year'] <= 2010))& (movies_df['Rating'] > 8.0)]
# Out:
#                           Rank                       Genre  \
# Title
# The Dark Knight             55          Action,Crime,Drama
# The Prestige                65        Drama,Mystery,Sci-Fi
# Inglourious Basterds        78         Adventure,Drama,War
# Inception                   81     Action,Adventure,Sci-Fi
# The Departed               100        Crime,Drama,Thriller
# No Country for Old Men     137        Crime,Drama,Thriller
# Shutter Island             139            Mystery,Thriller
# Into the Wild              198   Adventure,Biography,Drama
# Pan's Labyrinth            231           Drama,Fantasy,War
# There Will Be Blood        300               Drama,History
# The Bourne Ultimatum       428     Action,Mystery,Thriller
# 3 Idiots                   431                Comedy,Drama
# The Lives of Others        477              Drama,Thriller
# Up                         500  Animation,Adventure,Comedy
# WALL·E                     635  Animation,Adventure,Family
# ...

# %%
movies_df=pd.read_csv("fornite.csv",index_col="Title")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 movies_df=pd.read_csv("fornite.csv",index_col="Title")
#
# File c:\Users\FORYY\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\FORYY\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...
