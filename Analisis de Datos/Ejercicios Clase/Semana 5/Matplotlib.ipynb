# %%
pip install -U pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
plt.plot([4,8,13,17,20],[54, 67, 98, 78, 45])
plt.show() 
# un histograma sirve para ver la distribución de los datos en un conjunto de datos muy grande y ver la frecuencia de los datos en un rango de valores determinadob
